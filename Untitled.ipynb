# %%
import requests
from bs4 import BeautifulSoup
from random import choices

# %%
url = "https://realpython.com/tutorials/projects/"
page = requests.get(url)

print(page.text)
# Out:
# <!doctype html>
# <html lang="en">
#   <head>
#
#
#     <link href="https://files.realpython.com" rel="preconnect">
#
#     <title>Python Projects – Real Python</title>
#     <meta name="author" content="Real Python">
#     <meta name="description" content="Explore project-based Python tutorials and gain practical coding skills. Work on Python projects that help you gain real-world programming experience. These projects include full source code and step-by-step instructions, and will make you more confident in tackling real-world coding challenges.">
#     <meta name="keywords" content="">
#
#
#
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no, viewport-fit=cover">
#
#
#       <link rel="stylesheet" href="/static/realpython.min.12b12b3534b6.css">
#       <link rel="stylesheet" href="/static/gfonts/font.5ac42994de49.css">
#       <link rel="preload" href="/static/glightbox.min.9b438b29cef1.css" as="style" onload="this.onload=null;this.rel='stylesheet'"><noscript><link rel="stylesheet" href="/static/glightbox.min.9b438b29cef1.css"></noscript>
#
#
#
#
#
#
#       <link rel="canonical" href="https://realpython.com/tutorials/projects/">
#
#
#
#         <meta name="twitter:card" content="summary_large_image">
#         <meta name="twitter:image" content="https://files.realpython.com/media/13-Python-Projects-for-Intermediate-Developers_Watermarked.bb98d44bdb10.jpg">
#         <meta property="og:image" content="https://files.realpython.com/media/13-Python-Projects-for-Intermediate-Developers_Watermarked.bb98d44bdb10.jpg">
#
#       <meta name="twitter:creator" content="@realpython">
#       <meta name="twitter:site" content="@realpython">
#       <meta property="og:title" content="Python Projects – Real Python">
#       <meta property="og:type" content="article">
#       <meta property="og:url" content="https://realpython.com/tutorials/projects/">
#       <meta property="og:description" content="Explore project-based Python tutorials and gain practical coding skills. Work on Python projects that help you gain real-world programming experience. These projects include full source code and step-by-step instructions, and will make you more confident in tackling real-world coding challenges.">
#
#
#     <link href="/static/favicon.68cbf4197b0c.png" rel="icon">
#     <link href="https://realpython.com/atom.xml" rel="alternate" title="Real Python" type="application/atom+xml">
#     <link rel="manifest" href="/manifest.json">
#
#
#
#
#
#
#
#     <script id="icons-data" type="application/json">{"iconsUrl": "/static/icons.827db10c169f.svg"}</script>
#     <script id="optins-data" type="application/json">{"turnstileSiteKey": "0x4AAAAAAAQQUCLRXBi8NnUh"}</script>
#
#
#     <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#
#   ga('create', 'UA-35184939-1', 'auto', {'allowLinker': true});
#
#
#
#
#
#
#
#   ga('set', {
#     dimension1: false,
#     dimension2: false
#   });
#
#
#   ga('send', 'pageview');
#
# </script>
#
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-L7L6L5F6Y6"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'G-L7L6L5F6Y6');
#
#
# </script>
#
#   </head>
#   <body >
#
#
#
# <nav class="navbar fixed-top navbar-expand-lg navbar-dark flex-column ">
#   <div class="container flex-row">
#
#     <a class="navbar-brand" href="/">
#       <img src="/static/real-python-logo.893c30edea53.svg" width="165" height="40" class="d-inline-block align-top" alt="Real Python">
#     </a>
#
#
#     <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarSupportedContent" aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation">
#       <span class="navbar-toggler-icon"></span>
#     </button>
#
#     <div class="collapse navbar-collapse navbar-nav-scroll" id="navbarSupportedContent" role="navigation" aria-label="Main Navigation">
#
#       <ul class="navbar-nav mr-2">
#
#         <li class="nav-item">
#           <a class="nav-link" href="/start-here/">Start&nbsp;Here</a>
#         </li>
#
#         <li class="nav-item dropdown">
#           <a class="nav-link dropdown-toggle" href="#" id="navbarDropdownLibrary" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#             <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#brands--python"/></svg></span> Learn Python
#           </a>
#           <div class="dropdown-menu" aria-labelledby="navbarDropdownLibrary">
#
# <a class="dropdown-item " href="/search?kind=article&kind=course&order=newest" style="color: #ff7e73; line-height: 110%;"><span class="icon baseline mr-1"><svg><use href="/static/icons.827db10c169f.svg#solid--graduation-cap"/></svg></span>Python Tutorials&nbsp;→<br><small class="text-secondary">In-depth articles and video courses</small></a>
#
#
#
# <a class="dropdown-item " href="/learning-paths/" style="color: #ffc873; line-height: 110%;"><span class="icon baseline mr-1"><svg><use href="/static/icons.827db10c169f.svg#@learning-path"/></svg></span>Learning Paths&nbsp;→<br><small class="text-secondary">Guided study plans for accelerated learning</small></a>
#
#
#
# <a class="dropdown-item " href="/quizzes/" style="color: #abe0e5; line-height: 110%;"><span class="icon baseline mr-1"><svg><use href="/static/icons.827db10c169f.svg#@quiz"/></svg></span>Quizzes&nbsp;→<br><small class="text-secondary">Check your learning progress</small></a>
#
#
#
# <a class="dropdown-item " href="/tutorials/all/" style="color: #ccc; line-height: 110%;"><span class="icon baseline mr-1"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>Browse Topics&nbsp;→<br><small class="text-secondary">Focus on a specific area or skill level</small></a>
#
#
#
# <a class="dropdown-item " href="/community/" style="color: #e5c6ab; line-height: 110%;"><span class="icon baseline mr-1"><svg><use href="/static/icons.827db10c169f.svg#solid--message-smile"/></svg></span>Community Chat&nbsp;→<br><small class="text-secondary">Learn with other Pythonistas</small></a>
#
#
#
# <a class="dropdown-item " href="/office-hours/" style="color: #e5c6ab; line-height: 110%;"><span class="icon baseline mr-1"><svg><use href="/static/icons.827db10c169f.svg#solid--users"/></svg></span>Office Hours&nbsp;→<br><small class="text-secondary">Live Q&A calls with Python experts</small></a>
#
#
#
# <a class="dropdown-item " href="/podcasts/rpp/" style="color: #b8abe5; line-height: 110%;"><span class="icon baseline mr-1"><svg><use href="/static/icons.827db10c169f.svg#@podcast"/></svg></span>Podcast&nbsp;→<br><small class="text-secondary">Hear what’s new in the world of Python</small></a>
#
#
#
# <a class="dropdown-item " href="/products/books/" style="color: #abe5b1; line-height: 110%;"><span class="icon baseline mr-1"><svg><use href="/static/icons.827db10c169f.svg#solid--book-heart"/></svg></span>Books&nbsp;→<br><small class="text-secondary">Round out your knowledge and learn offline</small></a>
#
#
#
#
#
# <a class="dropdown-item border-top text-warning" href="/account/join/" style="line-height: 110%;"><span class="icon baseline mr-1"><svg><use href="/static/icons.827db10c169f.svg#solid--star"/></svg></span>Unlock All Content&nbsp;→</a>
#
#
#           </div>
#         </li>
#
#         <li class="nav-item dropdown">
#           <a class="nav-link dropdown-toggle" href="#" id="navbarDropdownMore" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#             More
#           </a>
#           <div class="dropdown-menu" aria-labelledby="navbarDropdownMore">
#             <a class="dropdown-item" href="/learner-stories/">Learner Stories</a>
#             <a class="dropdown-item" href="/newsletter/">Python Newsletter</a>
#             <a class="dropdown-item" href="https://www.pythonjobshq.com" target="_blank">Python Job Board</a>
#             <a class="dropdown-item" href="/team/">Meet the Team</a>
#             <a class="dropdown-item" href="/write-for-us/">Become a Tutorial Writer</a>
#             <a class="dropdown-item" href="/become-an-instructor/">Become a Video Instructor</a>
#           </div>
#         </li>
#
#       </ul>
#
#
#       <div class="d-block d-lg-none">
#         <ul class="navbar-nav">
#           <li class="nav-item">
#             <a class="nav-link" href="/search" title="Search"><span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#v4--search"/></svg></span> Search</a>
#           </li>
#         </ul>
#       </div>
#
#       <div class="d-none d-lg-flex align-items-center mr-2 flex-fill">
#         <form class="form-inline w-100 position-relative" action="/search" method="GET">
#           <a class="js-search-form-submit position-absolute" href="/search" title="Search"><span class="icon baseline text-muted pl-2"><svg><use href="/static/icons.827db10c169f.svg#v4--search"/></svg></span></a>
#           <input class="search-autocomplete search-field form-control form-control-md mr-sm-1 mr-lg-2 w-100" style="padding-left: 2rem;" maxlength=50 type="search" placeholder="Search" aria-label="Search" aria-keyshortcuts="/ Control+J Meta+J" name="q" autocomplete="off">
#           <span class="search-hotkey-indicator position-absolute px-2 border border-input text-input rounded small user-select-none" style="right: 1em;" title="Press / (forward slash) or Ctrl+J to open search" aria-hidden="true">/</span>
#           <input type="hidden" name="_from" value="nav">
#         </form>
#       </div>
#
#
#       <ul class="navbar-nav ml-auto">
#
#           <li class="nav-item form-inline">
#             <a class="ml-2 ml-lg-0 btn btn-sm btn-primary px-3" href="/account/join/">Join</a>
#           </li>
#           <li class="nav-item">
#             <a class="btn text-light" href="/account/login/?next=%2Ftutorials%2Fprojects%2F">Sign&#8209;In</a>
#           </li>
#
#       </ul>
#
#
#     </div>
#
#   </div>
#
#
#
# </nav>
#
#
#
#     <div class="container main-content">
#
#
#
#   <div class="row justify-content-center">
#
#
#     <aside class="col-md-7 col-lg-4 order-2 d-none d-lg-block">
#
#
#
#
#
#
# <div class="card mb-3 bg-secondary">
#   <form class="card-body" action="/optins/process/" method="post">
#     <div class="form-group">
#       <p class="h5 text-muted text-center">— FREE Email Series —</p>
#       <p class="h3 text-center">🐍 Python Tricks 💌</p>
#       <p><img loading="lazy" class="img-fluid rounded" src="/static/pytrick-dict-merge.4201a0125a5e.png" width="738" height="490" alt="Python Tricks Dictionary Merge"></p>
#     </div>
#     <div class="form-group">
#       <input type="hidden" name="csrfmiddlewaretoken" value="dMsg05J26OqWkZ0ang0uWNdFKRzK6cPEQQgB5dg9bdScBcxeciTKKTcdbd7AuRhv">
#       <input type="hidden" name="slug" value="static-python-tricks-sidebar">
#       <input type="email" class="form-control form-control-md" name="email" placeholder="Email&hellip;" required>
#     </div>
#     <button type="submit" name="submit" class="btn btn-primary btn-md btn-block">Get Python Tricks »</button>
#     <p class="mb-0 mt-2 text-muted text-center">🔒 No spam. Unsubscribe any time.</p>
#   </form>
# </div>
#
#
#
#
#
#
# <div class="sidebar-module sidebar-module-inset border">
#   <a href="/tutorials/all/" class="badge badge-light text-muted"><span class="icon baseline mr-1"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>Browse Topics</a>
#
#   <a href="/learning-paths/" class="badge badge-light text-muted"><span class="icon baseline mr-1"><svg><use href="/static/icons.827db10c169f.svg#solid--map-location-dot"/></svg></span>Guided Learning Paths</a>
#
#   <br>
#
#   <a href="/search?level=basics" class="badge badge-light text-muted"><span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#v4--angle-double-up"/></svg></span> Basics</a>
#
#   <a href="/search?level=intermediate" class="badge badge-light text-muted"><span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#v4--angle-double-up"/></svg></span><span class="icon baseline tight-left"><svg><use href="/static/icons.827db10c169f.svg#v4--angle-double-up"/></svg></span> Intermediate</a>
#
#   <a href="/search?level=advanced" class="badge badge-light text-muted"><span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#v4--angle-double-up"/></svg></span><span class="icon baseline tight-left"><svg><use href="/static/icons.827db10c169f.svg#v4--angle-double-up"/></svg></span><span class="icon baseline tight-left"><svg><use href="/static/icons.827db10c169f.svg#v4--angle-double-up"/></svg></span> Advanced</a>
#
#   <hr class="my-2">
#
#
#
#
#
#     <a href="/tutorials/api/" class="badge badge-light text-muted">api</a>
#
#
#
#
#
#     <a href="/tutorials/best-practices/" class="badge badge-light text-muted">best-practices</a>
#
#
#
#     <a href="/tutorials/career/" class="badge badge-light text-muted">career</a>
#
#
#
#     <a href="/tutorials/community/" class="badge badge-light text-muted">community</a>
#
#
#
#     <a href="/tutorials/databases/" class="badge badge-light text-muted">databases</a>
#
#
#
#     <a href="/tutorials/data-science/" class="badge badge-light text-muted">data-science</a>
#
#
#
#     <a href="/tutorials/data-structures/" class="badge badge-light text-muted">data-structures</a>
#
#
#
#     <a href="/tutorials/data-viz/" class="badge badge-light text-muted">data-viz</a>
#
#
#
#     <a href="/tutorials/devops/" class="badge badge-light text-muted">devops</a>
#
#
#
#     <a href="/tutorials/django/" class="badge badge-light text-muted">django</a>
#
#
#
#     <a href="/tutorials/docker/" class="badge badge-light text-muted">docker</a>
#
#
#
#     <a href="/tutorials/editors/" class="badge badge-light text-muted">editors</a>
#
#
#
#     <a href="/tutorials/flask/" class="badge badge-light text-muted">flask</a>
#
#
#
#     <a href="/tutorials/front-end/" class="badge badge-light text-muted">front-end</a>
#
#
#
#     <a href="/tutorials/gamedev/" class="badge badge-light text-muted">gamedev</a>
#
#
#
#     <a href="/tutorials/gui/" class="badge badge-light text-muted">gui</a>
#
#
#
#
#
#     <a href="/tutorials/machine-learning/" class="badge badge-light text-muted">machine-learning</a>
#
#
#
#     <a href="/tutorials/numpy/" class="badge badge-light text-muted">numpy</a>
#
#
#
#     <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#
#
#     <a href="/tutorials/python/" class="badge badge-light text-muted">python</a>
#
#
#
#     <a href="/tutorials/testing/" class="badge badge-light text-muted">testing</a>
#
#
#
#     <a href="/tutorials/tools/" class="badge badge-light text-muted">tools</a>
#
#
#
#     <a href="/tutorials/web-dev/" class="badge badge-light text-muted">web-dev</a>
#
#
#
#     <a href="/tutorials/web-scraping/" class="badge badge-light text-muted">web-scraping</a>
#
#
# </div>
#
#
#
# <div class="sidebar-module sidebar-module-inset p-0" style="overflow:hidden;">
#
# <div style="display:block;position:relative;">
#   <div style="display:block;width:100%;padding-top:100%;"></div>
#   <div class="rpad" data-unit="1x1" style="position:absolute;left:0;top:0;right:0;bottom:0;overflow:hidden;"></div>
# </div>
#
#
# </div>
#
#
#
#     </aside>
#
#     <div class="col-md-11 col-lg-8 article ">
#
#
#
# <nav aria-label="breadcrumb" role="navigation">
#   <ol class="breadcrumb border-bottom rounded-0">
#
#
#         <li class="breadcrumb-item " ><a href="/">Tutorials</a></li>
#
#
#
#         <li class="breadcrumb-item " ><a href="/tutorials/all/">Topics</a></li>
#
#
#
#         <li class="breadcrumb-item active" aria-current="page">Python Projects</li>
#
#
#   </ol>
# </nav>
#
#
#   <div class="mt-4 mb-5"><h1 id="python-projects-you-can-build">Python Projects You Can Build<a class="headerlink" href="#python-projects-you-can-build" title="Permanent link"></a></h1>
# <p>A common question by Python beginners and those at an intermediate skill-level is <em>&ldquo;Which Python projects should I work on to gain practical experience?&rdquo;</em></p>
# <p>You can use Python for web development, data science, desktop applications, and more. With so many options, it can be tough to choose your next <a href="https://realpython.com/intermediate-python-project-ideas/">project idea</a>&hellip; </p>
# <p><strong>On this page, you&rsquo;ll find example projects with step-by-step instructions that&rsquo;ll walk you through building real-world Python projects, from scratch.</strong></p>
# <p>Building hands-on projects will help you gain practical coding skills. One step at a time, you&rsquo;ll be putting your theoretical knowledge to use and build an impressive portfolio.</p>
# <p>Just pick a tutorial from the list below, and you&rsquo;ll have all of the sample code and instructions you&rsquo;ll need to have a finished project by the end:</p></div>
#
#
#
#
#
# <div class="d-flex mt-3 mb-4">
#   <form class="form-inline col p-0" action="/search" method="GET" id="search-form">
#     <a class="js-search-form-submit position-absolute" href="/search" title="Search"><span class="icon baseline text-muted pl-2"><svg><use href="/static/icons.827db10c169f.svg#@search"/></svg></span></a>
#     <input class="form-control form-control-lg w-100 " style="padding-left: 2rem;" maxlength=50 type="search" placeholder="Search in &ldquo;Python Projects&rdquo;&hellip;" aria-label="Search" name="q" autocomplete="off">
#     <input type="hidden" name="_from" value="category_index">
#     <input type="hidden" name="category" value="projects">
#
#   </form>
#   <button class="ml-3 btn btn-primary col-3 d-none d-lg-block" style="max-width: 250px;" type="submit" form="search-form">Search&nbsp;»</button>
# </div>
#
#
#   <div class="row">
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/courses/conway-game-of-life-python/">
#     <div class="embed-responsive embed-responsive-16by9">
#
#         <img loading="lazy" class="card-img-top m-0 p-0 embed-responsive-item rounded" style="object-fit: contain; background: #ffc774;" alt="Build Conway&#x27;s Game of Life With Python" src="https://files.realpython.com/media/Game-of-Life-by-John-H.-Conway-in-Python_Watermarked.a0f0041dfd78.jpg" width="1920" height="1080" srcset="/cdn-cgi/image/width=480,format=auto/https://files.realpython.com/media/Game-of-Life-by-John-H.-Conway-in-Python_Watermarked.a0f0041dfd78.jpg 480w, /cdn-cgi/image/width=640,format=auto/https://files.realpython.com/media/Game-of-Life-by-John-H.-Conway-in-Python_Watermarked.a0f0041dfd78.jpg 640w, /cdn-cgi/image/width=960,format=auto/https://files.realpython.com/media/Game-of-Life-by-John-H.-Conway-in-Python_Watermarked.a0f0041dfd78.jpg 960w, /cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/Game-of-Life-by-John-H.-Conway-in-Python_Watermarked.a0f0041dfd78.jpg 1920w" sizes="(min-width: 1200px) 330px, (min-width: 1000px) 290px, (min-width: 780px) 330px, (min-width: 580px) 510px, calc(100vw - 30px)">
#
#
#       <div class="card-img-overlay d-flex align-items-center">
#         <div class="mx-auto">
#           <span class="text-light" style="opacity: 0.90;"><span class="icon baseline scale3x"><svg><use href="/static/icons.827db10c169f.svg#@play"/></svg></span></span>
#         </div>
#       </div>
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/courses/conway-game-of-life-python/">
#       <h2 class="card-title h4 my-0 py-0">Create Conway&#x27;s Game of Life With Python</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#         <span class="mr-2">Feb 13, 2024</span>
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/gamedev/" class="badge badge-light text-muted">gamedev</a>
#
#           <a href="/tutorials/intermediate/" class="badge badge-light text-muted">intermediate</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#           <a href="/tutorials/python/" class="badge badge-light text-muted">python</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/courses/python-tic-tac-toe-ai/">
#     <div class="embed-responsive embed-responsive-16by9">
#
#         <img loading="lazy" class="card-img-top m-0 p-0 embed-responsive-item rounded" style="object-fit: contain; background: #aadfe5;" alt="Build a Tic-Tac-Toe Game Engine With an AI Player in Python" src="https://files.realpython.com/media/Build-an-AI-Game-Engine-for-Tic-Tac-Toe-in-Python_Watermarked.b90cdf84c417.jpg" width="1920" height="1080" srcset="/cdn-cgi/image/width=480,format=auto/https://files.realpython.com/media/Build-an-AI-Game-Engine-for-Tic-Tac-Toe-in-Python_Watermarked.b90cdf84c417.jpg 480w, /cdn-cgi/image/width=640,format=auto/https://files.realpython.com/media/Build-an-AI-Game-Engine-for-Tic-Tac-Toe-in-Python_Watermarked.b90cdf84c417.jpg 640w, /cdn-cgi/image/width=960,format=auto/https://files.realpython.com/media/Build-an-AI-Game-Engine-for-Tic-Tac-Toe-in-Python_Watermarked.b90cdf84c417.jpg 960w, /cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/Build-an-AI-Game-Engine-for-Tic-Tac-Toe-in-Python_Watermarked.b90cdf84c417.jpg 1920w" sizes="(min-width: 1200px) 330px, (min-width: 1000px) 290px, (min-width: 780px) 330px, (min-width: 580px) 510px, calc(100vw - 30px)">
#
#
#       <div class="card-img-overlay d-flex align-items-center">
#         <div class="mx-auto">
#           <span class="text-light" style="opacity: 0.90;"><span class="icon baseline scale3x"><svg><use href="/static/icons.827db10c169f.svg#@play"/></svg></span></span>
#         </div>
#       </div>
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/courses/python-tic-tac-toe-ai/">
#       <h2 class="card-title h4 my-0 py-0">Create a Tic-Tac-Toe Python Game Engine With an AI Player</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#         <span class="mr-2">Jan 16, 2024</span>
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/advanced/" class="badge badge-light text-muted">advanced</a>
#
#           <a href="/tutorials/best-practices/" class="badge badge-light text-muted">best-practices</a>
#
#           <a href="/tutorials/gamedev/" class="badge badge-light text-muted">gamedev</a>
#
#           <a href="/tutorials/gui/" class="badge badge-light text-muted">gui</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#           <a href="/tutorials/python/" class="badge badge-light text-muted">python</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/hangman-python-pysimplegui/">
#     <div class="embed-responsive embed-responsive-16by9">
#
#         <img loading="lazy" class="card-img-top m-0 p-0 embed-responsive-item rounded" style="object-fit: contain; background: #b9abe6;" alt="Build a Hangman Game With Python and PySimpleGUI" src="https://files.realpython.com/media/Build-a-Hangman-Game-With-Python-and-PySimpleGUI_Watermarked.6ad1f5a8158d.jpg" width="1920" height="1080" srcset="/cdn-cgi/image/width=480,format=auto/https://files.realpython.com/media/Build-a-Hangman-Game-With-Python-and-PySimpleGUI_Watermarked.6ad1f5a8158d.jpg 480w, /cdn-cgi/image/width=640,format=auto/https://files.realpython.com/media/Build-a-Hangman-Game-With-Python-and-PySimpleGUI_Watermarked.6ad1f5a8158d.jpg 640w, /cdn-cgi/image/width=960,format=auto/https://files.realpython.com/media/Build-a-Hangman-Game-With-Python-and-PySimpleGUI_Watermarked.6ad1f5a8158d.jpg 960w, /cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/Build-a-Hangman-Game-With-Python-and-PySimpleGUI_Watermarked.6ad1f5a8158d.jpg 1920w" sizes="(min-width: 1200px) 330px, (min-width: 1000px) 290px, (min-width: 780px) 330px, (min-width: 580px) 510px, calc(100vw - 30px)">
#
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/hangman-python-pysimplegui/">
#       <h2 class="card-title h4 my-0 py-0">Build a Hangman Game With Python and PySimpleGUI</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#         <span class="mr-2">Dec 06, 2023</span>
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/basics/" class="badge badge-light text-muted">basics</a>
#
#           <a href="/tutorials/gamedev/" class="badge badge-light text-muted">gamedev</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#           <a href="/tutorials/python/" class="badge badge-light text-muted">python</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/conway-game-of-life-python/">
#     <div class="embed-responsive embed-responsive-16by9">
#
#         <img loading="lazy" class="card-img-top m-0 p-0 embed-responsive-item rounded" style="object-fit: contain; background: #ffc774;" alt="Build Conway&#x27;s Game of Life With Python" src="https://files.realpython.com/media/Game-of-Life-by-John-H.-Conway-in-Python_Watermarked.a0f0041dfd78.jpg" width="1920" height="1080" srcset="/cdn-cgi/image/width=480,format=auto/https://files.realpython.com/media/Game-of-Life-by-John-H.-Conway-in-Python_Watermarked.a0f0041dfd78.jpg 480w, /cdn-cgi/image/width=640,format=auto/https://files.realpython.com/media/Game-of-Life-by-John-H.-Conway-in-Python_Watermarked.a0f0041dfd78.jpg 640w, /cdn-cgi/image/width=960,format=auto/https://files.realpython.com/media/Game-of-Life-by-John-H.-Conway-in-Python_Watermarked.a0f0041dfd78.jpg 960w, /cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/Game-of-Life-by-John-H.-Conway-in-Python_Watermarked.a0f0041dfd78.jpg 1920w" sizes="(min-width: 1200px) 330px, (min-width: 1000px) 290px, (min-width: 780px) 330px, (min-width: 580px) 510px, calc(100vw - 30px)">
#
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/conway-game-of-life-python/">
#       <h2 class="card-title h4 my-0 py-0">Build Conway&#x27;s Game of Life With Python</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#         <span class="mr-2">Nov 22, 2023</span>
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/gamedev/" class="badge badge-light text-muted">gamedev</a>
#
#           <a href="/tutorials/intermediate/" class="badge badge-light text-muted">intermediate</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#           <a href="/tutorials/python/" class="badge badge-light text-muted">python</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/python-hangman/">
#     <div class="embed-responsive embed-responsive-16by9">
#
#         <img loading="lazy" class="card-img-top m-0 p-0 embed-responsive-item rounded" style="object-fit: contain; background: #e5c5ac;" alt="Build a Hangman Game for the Command Line in Python" src="https://files.realpython.com/media/Make-a-Hangman-Game-with-Python_Watermarked1.8755c369083d.jpg" width="1920" height="1080" srcset="/cdn-cgi/image/width=480,format=auto/https://files.realpython.com/media/Make-a-Hangman-Game-with-Python_Watermarked1.8755c369083d.jpg 480w, /cdn-cgi/image/width=640,format=auto/https://files.realpython.com/media/Make-a-Hangman-Game-with-Python_Watermarked1.8755c369083d.jpg 640w, /cdn-cgi/image/width=960,format=auto/https://files.realpython.com/media/Make-a-Hangman-Game-with-Python_Watermarked1.8755c369083d.jpg 960w, /cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/Make-a-Hangman-Game-with-Python_Watermarked1.8755c369083d.jpg 1920w" sizes="(min-width: 1200px) 330px, (min-width: 1000px) 290px, (min-width: 780px) 330px, (min-width: 580px) 510px, calc(100vw - 30px)">
#
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/python-hangman/">
#       <h2 class="card-title h4 my-0 py-0">Build a Hangman Game for the Command Line in Python</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#         <span class="mr-2">Nov 01, 2023</span>
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/basics/" class="badge badge-light text-muted">basics</a>
#
#           <a href="/tutorials/gamedev/" class="badge badge-light text-muted">gamedev</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#           <a href="/tutorials/python/" class="badge badge-light text-muted">python</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/build-a-blog-from-scratch-django/">
#     <div class="embed-responsive embed-responsive-16by9">
#
#         <img loading="lazy" class="card-img-top m-0 p-0 embed-responsive-item rounded" style="object-fit: contain; background: #b9abe6;" alt="Build a Blog From Scratch With Django" src="https://files.realpython.com/media/Create-Your-Own-Blog-With-Django_Watermarked.e6c0d57bc55a.jpg" width="1920" height="1080" srcset="/cdn-cgi/image/width=480,format=auto/https://files.realpython.com/media/Create-Your-Own-Blog-With-Django_Watermarked.e6c0d57bc55a.jpg 480w, /cdn-cgi/image/width=640,format=auto/https://files.realpython.com/media/Create-Your-Own-Blog-With-Django_Watermarked.e6c0d57bc55a.jpg 640w, /cdn-cgi/image/width=960,format=auto/https://files.realpython.com/media/Create-Your-Own-Blog-With-Django_Watermarked.e6c0d57bc55a.jpg 960w, /cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/Create-Your-Own-Blog-With-Django_Watermarked.e6c0d57bc55a.jpg 1920w" sizes="(min-width: 1200px) 330px, (min-width: 1000px) 290px, (min-width: 780px) 330px, (min-width: 580px) 510px, calc(100vw - 30px)">
#
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/build-a-blog-from-scratch-django/">
#       <h2 class="card-title h4 my-0 py-0">Build a Blog From Scratch With Django</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#         <span class="mr-2">Oct 16, 2023</span>
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/django/" class="badge badge-light text-muted">django</a>
#
#           <a href="/tutorials/intermediate/" class="badge badge-light text-muted">intermediate</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#           <a href="/tutorials/web-dev/" class="badge badge-light text-muted">web-dev</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/get-started-with-django-1/">
#     <div class="embed-responsive embed-responsive-16by9">
#
#         <img loading="lazy" class="card-img-top m-0 p-0 embed-responsive-item rounded" style="object-fit: contain; background: #ffc873;" alt="Get Started With Django Part 1: Build a Portfolio App" src="https://files.realpython.com/media/Get-Started-With-Django_Watermarked.15a1e05597bc.jpg" width="1920" height="1080" srcset="/cdn-cgi/image/width=480,format=auto/https://files.realpython.com/media/Get-Started-With-Django_Watermarked.15a1e05597bc.jpg 480w, /cdn-cgi/image/width=640,format=auto/https://files.realpython.com/media/Get-Started-With-Django_Watermarked.15a1e05597bc.jpg 640w, /cdn-cgi/image/width=960,format=auto/https://files.realpython.com/media/Get-Started-With-Django_Watermarked.15a1e05597bc.jpg 960w, /cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/Get-Started-With-Django_Watermarked.15a1e05597bc.jpg 1920w" sizes="(min-width: 1200px) 330px, (min-width: 1000px) 290px, (min-width: 780px) 330px, (min-width: 580px) 510px, calc(100vw - 30px)">
#
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/get-started-with-django-1/">
#       <h2 class="card-title h4 my-0 py-0">Get Started With Django: Build a Portfolio App</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#         <span class="mr-2">Aug 30, 2023</span>
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/django/" class="badge badge-light text-muted">django</a>
#
#           <a href="/tutorials/intermediate/" class="badge badge-light text-muted">intermediate</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#           <a href="/tutorials/web-dev/" class="badge badge-light text-muted">web-dev</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/courses/python-wordle-clone/">
#     <div class="embed-responsive embed-responsive-16by9">
#
#         <img loading="lazy" class="card-img-top m-0 p-0 embed-responsive-item rounded" style="object-fit: contain; background: #b9abe6;" alt="Build a Wordle Clone With Python and Rich" src="https://files.realpython.com/media/Build-a-Wordle-Clone-in-Python-with-Rich_Watermarked.f0c041c03a5e.jpg" width="1920" height="1080" srcset="/cdn-cgi/image/width=480,format=auto/https://files.realpython.com/media/Build-a-Wordle-Clone-in-Python-with-Rich_Watermarked.f0c041c03a5e.jpg 480w, /cdn-cgi/image/width=640,format=auto/https://files.realpython.com/media/Build-a-Wordle-Clone-in-Python-with-Rich_Watermarked.f0c041c03a5e.jpg 640w, /cdn-cgi/image/width=960,format=auto/https://files.realpython.com/media/Build-a-Wordle-Clone-in-Python-with-Rich_Watermarked.f0c041c03a5e.jpg 960w, /cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/Build-a-Wordle-Clone-in-Python-with-Rich_Watermarked.f0c041c03a5e.jpg 1920w" sizes="(min-width: 1200px) 330px, (min-width: 1000px) 290px, (min-width: 780px) 330px, (min-width: 580px) 510px, calc(100vw - 30px)">
#
#
#       <div class="card-img-overlay d-flex align-items-center">
#         <div class="mx-auto">
#           <span class="text-light" style="opacity: 0.90;"><span class="icon baseline scale3x"><svg><use href="/static/icons.827db10c169f.svg#@play"/></svg></span></span>
#         </div>
#       </div>
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/courses/python-wordle-clone/">
#       <h2 class="card-title h4 my-0 py-0">Create a Python Wordle Clone With Rich</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#         <span class="mr-2">Aug 29, 2023</span>
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/basics/" class="badge badge-light text-muted">basics</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/python-code-image-generator/">
#     <div class="embed-responsive embed-responsive-16by9">
#
#         <img loading="lazy" class="card-img-top m-0 p-0 embed-responsive-item rounded" style="object-fit: contain; background: #b9abe6;" alt="Build a Code Image Generator With Python" src="https://files.realpython.com/media/Build-a-Code-Picture-App-with-Flask-Pygments-and-Playwright_Watermarked.b86809c18608.jpg" width="1920" height="1080" srcset="/cdn-cgi/image/width=480,format=auto/https://files.realpython.com/media/Build-a-Code-Picture-App-with-Flask-Pygments-and-Playwright_Watermarked.b86809c18608.jpg 480w, /cdn-cgi/image/width=640,format=auto/https://files.realpython.com/media/Build-a-Code-Picture-App-with-Flask-Pygments-and-Playwright_Watermarked.b86809c18608.jpg 640w, /cdn-cgi/image/width=960,format=auto/https://files.realpython.com/media/Build-a-Code-Picture-App-with-Flask-Pygments-and-Playwright_Watermarked.b86809c18608.jpg 960w, /cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/Build-a-Code-Picture-App-with-Flask-Pygments-and-Playwright_Watermarked.b86809c18608.jpg 1920w" sizes="(min-width: 1200px) 330px, (min-width: 1000px) 290px, (min-width: 780px) 330px, (min-width: 580px) 510px, calc(100vw - 30px)">
#
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/python-code-image-generator/">
#       <h2 class="card-title h4 my-0 py-0">Build a Code Image Generator With Python</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#         <span class="mr-2">Aug 21, 2023</span>
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/flask/" class="badge badge-light text-muted">flask</a>
#
#           <a href="/tutorials/front-end/" class="badge badge-light text-muted">front-end</a>
#
#           <a href="/tutorials/intermediate/" class="badge badge-light text-muted">intermediate</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#           <a href="/tutorials/web-dev/" class="badge badge-light text-muted">web-dev</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/courses/python-maze-solver/">
#     <div class="embed-responsive embed-responsive-16by9">
#
#         <img loading="lazy" class="card-img-top m-0 p-0 embed-responsive-item rounded" style="object-fit: contain; background: #b8aae5;" alt="Build a Maze Solver in Python Using Graphs" src="https://files.realpython.com/media/Build-a-Pac-Man-Maze-Solver-in-Python_Watermarked.c2e79a85fc99.jpg" width="1920" height="1080" srcset="/cdn-cgi/image/width=480,format=auto/https://files.realpython.com/media/Build-a-Pac-Man-Maze-Solver-in-Python_Watermarked.c2e79a85fc99.jpg 480w, /cdn-cgi/image/width=640,format=auto/https://files.realpython.com/media/Build-a-Pac-Man-Maze-Solver-in-Python_Watermarked.c2e79a85fc99.jpg 640w, /cdn-cgi/image/width=960,format=auto/https://files.realpython.com/media/Build-a-Pac-Man-Maze-Solver-in-Python_Watermarked.c2e79a85fc99.jpg 960w, /cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/Build-a-Pac-Man-Maze-Solver-in-Python_Watermarked.c2e79a85fc99.jpg 1920w" sizes="(min-width: 1200px) 330px, (min-width: 1000px) 290px, (min-width: 780px) 330px, (min-width: 580px) 510px, calc(100vw - 30px)">
#
#
#       <div class="card-img-overlay d-flex align-items-center">
#         <div class="mx-auto">
#           <span class="text-light" style="opacity: 0.90;"><span class="icon baseline scale3x"><svg><use href="/static/icons.827db10c169f.svg#@play"/></svg></span></span>
#         </div>
#       </div>
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/courses/python-maze-solver/">
#       <h2 class="card-title h4 my-0 py-0">Mazes in Python: Build, Visualize, Store, and Solve</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#         <span class="mr-2">Jun 06, 2023</span>
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/intermediate/" class="badge badge-light text-muted">intermediate</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/python-maze-solver/">
#     <div class="embed-responsive embed-responsive-16by9">
#
#         <img loading="lazy" class="card-img-top m-0 p-0 embed-responsive-item rounded" style="object-fit: contain; background: #b8aae5;" alt="Build a Maze Solver in Python Using Graphs" src="https://files.realpython.com/media/Build-a-Pac-Man-Maze-Solver-in-Python_Watermarked.c2e79a85fc99.jpg" width="1920" height="1080" srcset="/cdn-cgi/image/width=480,format=auto/https://files.realpython.com/media/Build-a-Pac-Man-Maze-Solver-in-Python_Watermarked.c2e79a85fc99.jpg 480w, /cdn-cgi/image/width=640,format=auto/https://files.realpython.com/media/Build-a-Pac-Man-Maze-Solver-in-Python_Watermarked.c2e79a85fc99.jpg 640w, /cdn-cgi/image/width=960,format=auto/https://files.realpython.com/media/Build-a-Pac-Man-Maze-Solver-in-Python_Watermarked.c2e79a85fc99.jpg 960w, /cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/Build-a-Pac-Man-Maze-Solver-in-Python_Watermarked.c2e79a85fc99.jpg 1920w" sizes="(min-width: 1200px) 330px, (min-width: 1000px) 290px, (min-width: 780px) 330px, (min-width: 580px) 510px, calc(100vw - 30px)">
#
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/python-maze-solver/">
#       <h2 class="card-title h4 my-0 py-0">Build a Maze Solver in Python Using Graphs</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#         <span class="mr-2">Mar 29, 2023</span>
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/intermediate/" class="badge badge-light text-muted">intermediate</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/python-wordle-clone/">
#     <div class="embed-responsive embed-responsive-16by9">
#
#         <img loading="lazy" class="card-img-top m-0 p-0 embed-responsive-item rounded" style="object-fit: contain; background: #b9abe6;" alt="Build a Wordle Clone With Python and Rich" src="https://files.realpython.com/media/Build-a-Wordle-Clone-in-Python-with-Rich_Watermarked.f0c041c03a5e.jpg" width="1920" height="1080" srcset="/cdn-cgi/image/width=480,format=auto/https://files.realpython.com/media/Build-a-Wordle-Clone-in-Python-with-Rich_Watermarked.f0c041c03a5e.jpg 480w, /cdn-cgi/image/width=640,format=auto/https://files.realpython.com/media/Build-a-Wordle-Clone-in-Python-with-Rich_Watermarked.f0c041c03a5e.jpg 640w, /cdn-cgi/image/width=960,format=auto/https://files.realpython.com/media/Build-a-Wordle-Clone-in-Python-with-Rich_Watermarked.f0c041c03a5e.jpg 960w, /cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/Build-a-Wordle-Clone-in-Python-with-Rich_Watermarked.f0c041c03a5e.jpg 1920w" sizes="(min-width: 1200px) 330px, (min-width: 1000px) 290px, (min-width: 780px) 330px, (min-width: 580px) 510px, calc(100vw - 30px)">
#
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/python-wordle-clone/">
#       <h2 class="card-title h4 my-0 py-0">Build a Wordle Clone With Python and Rich</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/basics/" class="badge badge-light text-muted">basics</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/flask-javascript-frontend-for-rest-api/">
#     <div class="embed-responsive embed-responsive-16by9">
#
#         <img loading="lazy" class="card-img-top m-0 p-0 embed-responsive-item rounded" style="object-fit: contain; background: #ff7e74;" alt="Build a JavaScript Front End for a Flask API" src="https://files.realpython.com/media/Build-a-Frontend-for-a-REST-API_Watermarked.04a2d8050465.jpg" width="1920" height="1080" srcset="/cdn-cgi/image/width=480,format=auto/https://files.realpython.com/media/Build-a-Frontend-for-a-REST-API_Watermarked.04a2d8050465.jpg 480w, /cdn-cgi/image/width=640,format=auto/https://files.realpython.com/media/Build-a-Frontend-for-a-REST-API_Watermarked.04a2d8050465.jpg 640w, /cdn-cgi/image/width=960,format=auto/https://files.realpython.com/media/Build-a-Frontend-for-a-REST-API_Watermarked.04a2d8050465.jpg 960w, /cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/Build-a-Frontend-for-a-REST-API_Watermarked.04a2d8050465.jpg 1920w" sizes="(min-width: 1200px) 330px, (min-width: 1000px) 290px, (min-width: 780px) 330px, (min-width: 580px) 510px, calc(100vw - 30px)">
#
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/flask-javascript-frontend-for-rest-api/">
#       <h2 class="card-title h4 my-0 py-0">Build a JavaScript Front End for a Flask API</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/api/" class="badge badge-light text-muted">api</a>
#
#           <a href="/tutorials/flask/" class="badge badge-light text-muted">flask</a>
#
#           <a href="/tutorials/front-end/" class="badge badge-light text-muted">front-end</a>
#
#           <a href="/tutorials/intermediate/" class="badge badge-light text-muted">intermediate</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#           <a href="/tutorials/web-dev/" class="badge badge-light text-muted">web-dev</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/tic-tac-toe-ai-python/">
#     <div class="embed-responsive embed-responsive-16by9">
#
# ...
#
#
#       <div class="card-img-overlay d-flex align-items-center">
#         <div class="mx-auto">
#           <span class="text-light" style="opacity: 0.90;"><span class="icon baseline scale3x"><svg><use href="/static/icons.827db10c169f.svg#@play"/></svg></span></span>
#         </div>
#       </div>
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/courses/discord-bot-python/">
#       <h2 class="card-title h4 my-0 py-0">Creating a Discord Bot in Python</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/api/" class="badge badge-light text-muted">api</a>
#
#           <a href="/tutorials/intermediate/" class="badge badge-light text-muted">intermediate</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/python-raspberry-pi/">
#     <div class="embed-responsive embed-responsive-16by9">
#
#         <img loading="lazy" class="card-img-top m-0 p-0 embed-responsive-item rounded" style="object-fit: contain; background: #ff7e74;" alt="Build Physical Projects With Python on the Raspberry Pi" src="https://files.realpython.com/media/Getting-Started-With-Python-on-Raspberry-Pi_Watermarked.be0a53816c48.jpg" width="1920" height="1080" srcset="/cdn-cgi/image/width=480,format=auto/https://files.realpython.com/media/Getting-Started-With-Python-on-Raspberry-Pi_Watermarked.be0a53816c48.jpg 480w, /cdn-cgi/image/width=640,format=auto/https://files.realpython.com/media/Getting-Started-With-Python-on-Raspberry-Pi_Watermarked.be0a53816c48.jpg 640w, /cdn-cgi/image/width=960,format=auto/https://files.realpython.com/media/Getting-Started-With-Python-on-Raspberry-Pi_Watermarked.be0a53816c48.jpg 960w, /cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/Getting-Started-With-Python-on-Raspberry-Pi_Watermarked.be0a53816c48.jpg 1920w" sizes="(min-width: 1200px) 330px, (min-width: 1000px) 290px, (min-width: 780px) 330px, (min-width: 580px) 510px, calc(100vw - 30px)">
#
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/python-raspberry-pi/">
#       <h2 class="card-title h4 my-0 py-0">Build Physical Projects With Python on the Raspberry Pi</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/intermediate/" class="badge badge-light text-muted">intermediate</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/installable-django-app/">
#     <div class="embed-responsive embed-responsive-16by9">
#
#         <img loading="lazy" class="card-img-top m-0 p-0 embed-responsive-item rounded" style="object-fit: contain; background: #ffc873;" alt="How to Write an Installable Django App" src="https://files.realpython.com/media/Writing-an-Installable-Django-App_Watermarked.edfa68acb353.jpg" width="1920" height="1080" srcset="/cdn-cgi/image/width=480,format=auto/https://files.realpython.com/media/Writing-an-Installable-Django-App_Watermarked.edfa68acb353.jpg 480w, /cdn-cgi/image/width=640,format=auto/https://files.realpython.com/media/Writing-an-Installable-Django-App_Watermarked.edfa68acb353.jpg 640w, /cdn-cgi/image/width=960,format=auto/https://files.realpython.com/media/Writing-an-Installable-Django-App_Watermarked.edfa68acb353.jpg 960w, /cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/Writing-an-Installable-Django-App_Watermarked.edfa68acb353.jpg 1920w" sizes="(min-width: 1200px) 330px, (min-width: 1000px) 290px, (min-width: 780px) 330px, (min-width: 580px) 510px, calc(100vw - 30px)">
#
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/installable-django-app/">
#       <h2 class="card-title h4 my-0 py-0">How to Write an Installable Django App</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/advanced/" class="badge badge-light text-muted">advanced</a>
#
#           <a href="/tutorials/django/" class="badge badge-light text-muted">django</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#           <a href="/tutorials/testing/" class="badge badge-light text-muted">testing</a>
#
#           <a href="/tutorials/web-dev/" class="badge badge-light text-muted">web-dev</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/courses/structuring-python-application/">
#     <div class="embed-responsive embed-responsive-16by9">
#
#         <img loading="lazy" class="card-img-top m-0 p-0 embed-responsive-item rounded" style="object-fit: contain; background: #abe0e6;" alt="Python Application Layouts and Project Structures" src="https://files.realpython.com/media/python_application_layout_watermark.31a037620d92.jpg" width="1920" height="1080" srcset="/cdn-cgi/image/width=480,format=auto/https://files.realpython.com/media/python_application_layout_watermark.31a037620d92.jpg 480w, /cdn-cgi/image/width=640,format=auto/https://files.realpython.com/media/python_application_layout_watermark.31a037620d92.jpg 640w, /cdn-cgi/image/width=960,format=auto/https://files.realpython.com/media/python_application_layout_watermark.31a037620d92.jpg 960w, /cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/python_application_layout_watermark.31a037620d92.jpg 1920w" sizes="(min-width: 1200px) 330px, (min-width: 1000px) 290px, (min-width: 780px) 330px, (min-width: 580px) 510px, calc(100vw - 30px)">
#
#
#       <div class="card-img-overlay d-flex align-items-center">
#         <div class="mx-auto">
#           <span class="text-light" style="opacity: 0.90;"><span class="icon baseline scale3x"><svg><use href="/static/icons.827db10c169f.svg#@play"/></svg></span></span>
#         </div>
#       </div>
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/courses/structuring-python-application/">
#       <h2 class="card-title h4 my-0 py-0">Structuring a Python Application</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/basics/" class="badge badge-light text-muted">basics</a>
#
#           <a href="/tutorials/best-practices/" class="badge badge-light text-muted">best-practices</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#       <div class="col-12 col-md-6 mb-5">
#
#
#
# <div class="card border-0">
#   <a href="/instagram-bot-python-instapy/">
#     <div class="embed-responsive embed-responsive-16by9">
#
#         <img loading="lazy" class="card-img-top m-0 p-0 embed-responsive-item rounded" style="object-fit: contain; background: #e5c5ac;" alt="How to Make an Instagram Bot With Python and InstaPy" src="https://files.realpython.com/media/How-to-Make-an-Instagram-Bot-With-InstaPy_Watermarked.1e87c3f0beed.jpg" width="1920" height="1080" srcset="/cdn-cgi/image/width=480,format=auto/https://files.realpython.com/media/How-to-Make-an-Instagram-Bot-With-InstaPy_Watermarked.1e87c3f0beed.jpg 480w, /cdn-cgi/image/width=640,format=auto/https://files.realpython.com/media/How-to-Make-an-Instagram-Bot-With-InstaPy_Watermarked.1e87c3f0beed.jpg 640w, /cdn-cgi/image/width=960,format=auto/https://files.realpython.com/media/How-to-Make-an-Instagram-Bot-With-InstaPy_Watermarked.1e87c3f0beed.jpg 960w, /cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/How-to-Make-an-Instagram-Bot-With-InstaPy_Watermarked.1e87c3f0beed.jpg 1920w" sizes="(min-width: 1200px) 330px, (min-width: 1000px) 290px, (min-width: 780px) 330px, (min-width: 580px) 510px, calc(100vw - 30px)">
#
#
#     </div>
#   </a>
#   <div class="card-body m-0 p-0 mt-2">
#     <a class=" " href="/instagram-bot-python-instapy/">
#       <h2 class="card-title h4 my-0 py-0">How to Make an Instagram Bot With Python and InstaPy</h2>
#     </a>
#     <p class="card-text text-muted text-truncate small">
#
#
#
#         <span class="icon baseline"><svg><use href="/static/icons.827db10c169f.svg#@category"/></svg></span>
#
#           <a href="/tutorials/intermediate/" class="badge badge-light text-muted">intermediate</a>
#
#           <a href="/tutorials/projects/" class="badge badge-light text-muted">projects</a>
#
#
#     </p>
#   </div>
# </div>
#
#       </div>
#
#   </div>
#
#
#
#     <nav aria-label="Page Navigation">
#       <ul class="pagination pagination-lg justify-content-center">
#
#           <li class="page-item disabled"><a class="page-link">«</a></li>
#
#
#
#             <li class="page-item active"><a class="page-link">1</a></li>
#
#
#
#             <li class="page-item"><a class="page-link" href="/tutorials/projects/page/2/">2</a></li>
#
#
#
#           <li class="page-item"><a class="page-link" href="/tutorials/projects/page/2/">»</a></li>
#
#       </ul>
#     </nav>
#
#
#   <div class="sidebar-module sidebar-module-inset p-0" style="overflow:hidden;">
#
# <div style="display:block;position:relative;">
#   <div style="display:block;width:100%;padding-top:25%;"></div>
#   <div class="rpad" data-unit="4x1" style="position:absolute;left:0;top:0;right:0;bottom:0;overflow:hidden;"></div>
# </div>
#
#
#   </div>
#
#     </div>
#
#   </div>
#
#     </div>
#
#
#
#
#
#
#
#
#
# <footer class="footer">
#   <div class="container">
#
#
#     <p class="text-center text-muted w-75 mx-auto">© 2012–2024 Real&nbsp;Python&nbsp;⋅ <a href="/newsletter/">Newsletter</a>&nbsp;⋅ <a href="/podcasts/rpp/">Podcast</a>&nbsp;⋅ <a href="https://www.youtube.com/realpython">YouTube</a>&nbsp;⋅ <a href="https://twitter.com/realpython">Twitter</a>&nbsp;⋅ <a href="https://facebook.com/LearnRealPython">Facebook</a>&nbsp;⋅ <a href="https://www.instagram.com/realpython/">Instagram</a>&nbsp;⋅ <a href="/">Python&nbsp;Tutorials</a>&nbsp;⋅ <a href="/search">Search</a>&nbsp;⋅ <a href="/privacy-policy/">Privacy Policy</a>&nbsp;⋅ <a href="/energy-policy/">Energy Policy</a>&nbsp;⋅ <a href="/sponsorships/">Advertise</a>&nbsp;⋅ <a href="/contact/">Contact</a><br><span class="icon baseline text-color-red"><svg><use href="/static/icons.827db10c169f.svg#solid--heart"/></svg></span> Happy Pythoning!</p>
#   </div>
# </footer>
#
#
#
#
#     <script>
#       (function() {
#         var isAndroid = navigator.userAgent.toLowerCase().indexOf("android") > -1;
#         if (!isAndroid) {
#           return;
#         }
#
#         var styles = `
#         @font-face {
#           font-family: 'DejaVu Sans Mono';
#           font-weight: normal;
#           font-style: normal;
#           font-display: swap;
#           src: url('/static/mfonts/dejavu-sans-mono.33f00225f915.woff2') format('woff2'),
#                url('/static/mfonts/dejavu-sans-mono.0da77d3739f3.woff') format('woff'),
#                url('/static/mfonts/dejavu-sans-mono.c2356fc49835.ttf') format('truetype');
#         }
#         code, kbd, pre, samp {
#           font-family: 'DejaVu Sans Mono', monospace;
#         }
#         `
#
#         var styleSheet = document.createElement("style")
#         styleSheet.type = "text/css"
#         styleSheet.innerText = styles
#         document.head.appendChild(styleSheet)
#       })();
#     </script>
#
#
#
#     <script src="/static/jquery.min.00727d1d5d9c.js"></script>
#     <script src="/static/popper.min.47dc3aaf2942.js"></script>
#     <script src="/static/bootstrap.min.a3b2689424c3.js"></script>
#
#
#
#
#     <script>
#     (function() {
#       document.querySelectorAll(".js-search-form-submit").forEach(function(el) {
#         el.addEventListener("click", function(e) {
#           e.preventDefault();
#           e.currentTarget.parentElement.submit();
#         })
#       });
#     })();
#     </script>
#     <script src="/static/frontend/reader/codeblock.5c8399b698d9.js" async></script>
#     <script src="/static/frontend/reader/lightbox.45ed8c5a3d27.js" async></script>
#     <script src="/static/frontend/reader/platforms-ui.b11202dc6079.js" async></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script>window.rp_prop_id = '58946116052';</script>
# <script src="https://srv.realpython.net/tag.js" async></script>
#
#
#
#
#     <script src="/static/frontend/optins/optins.12ffd39288e9.js" async></script>
#     <script src="/static/frontend/search/autocomplete.5cf5140902a7.js" async></script>
#
#
#
#
#
#
#
#
#
#
# <script>
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '2220911568135371');
#   fbq('track', 'PageView');
# </script>
# <noscript><img height="1" width="1" style="display:none"
#   src="https://www.facebook.com/tr?id=2220911568135371&ev=PageView&noscript=1"
# /></noscript>
#
#
#
#
#
#
#   <script>(function(){var js = "window['__CF$cv$params']={r:'861e9291699806da',t:'MTcxMDAyNDA4Ny41ODAwMDA='};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();</script></body>
# </html>

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
python_projects = soup.find_all('div', class_="col-12 col-md-6 mb-5")
projects_title = []
for projects in python_projects:
    title = projects.find("h2", class_="card-title")
    level = projects.find("a", class_="badge badge-light text-muted")
    print(title.text)
    print(level.text)
    projects_title.append(title.text + " " + level.text)
projects_title
# Out:
# Create Conway's Game of Life With Python
# gamedev
# Create a Tic-Tac-Toe Python Game Engine With an AI Player
# advanced
# Build a Hangman Game With Python and PySimpleGUI
# basics
# Build Conway's Game of Life With Python
# gamedev
# Build a Hangman Game for the Command Line in Python
# basics
# Build a Blog From Scratch With Django
# django
# Get Started With Django: Build a Portfolio App
# django
# Create a Python Wordle Clone With Rich
# basics
# Build a Code Image Generator With Python
# flask
# Mazes in Python: Build, Visualize, Store, and Solve
# intermediate
# Build a Maze Solver in Python Using Graphs
# intermediate
# Build a Wordle Clone With Python and Rich
# basics
# Build a JavaScript Front End for a Flask API
# api
# Build a Tic-Tac-Toe Game Engine With an AI Player in Python
# advanced
# ChatterBot: Build a Chatbot With Python
# data-science
# Building Python Project Documentation With MkDocs
# intermediate
# Python and PyQt: Building a GUI Desktop Calculator
# gui
# Building a URL Shortener With FastAPI and Python
# api
# Build a Flashcards App With Django
# django
# Building a Site Connectivity Checker
# intermediate
# Build Your Python Project Documentation With MkDocs
# basics
# Build a Quiz Application With Python
# basics
# Build a URL Shortener With FastAPI and Python
# api
# Build a Site Connectivity Checker in Python
# intermediate
# Manage Your To-Do Lists Using Python and Django
# basics
# Build a Dice-Rolling Application With Python
# basics
# Build a Command-Line To-Do App With Python and Typer
# intermediate
# Build a Content Aggregator in Python
# intermediate
# Using Pygame to Build an Asteroids Game in Python
# gamedev
# Hosting a Django Project on Heroku
# django
# Rock, Paper, Scissors With Python: A Command Line Game
# basics
# Build a Personal Diary With Django and Python
# basics
# Using sleep() to Code a Python Uptime Bot
# intermediate
# Using pandas to Make a Gradebook in Python
# advanced
# Build a Bulk File Rename Tool With Python and PyQt
# gui
# Build a Python Directory Tree Generator for the Command Line
# intermediate
# Start Contributing to Python: Your First Steps
# career
# Build an Asteroids Game With Python and Pygame
# gamedev
# Build a Contact Book With Python, PyQt, and SQLite
# databases
# Make Your First Python Game: Rock, Paper, Scissors!
# basics
# Practical Recipes for Working With Files in Python
# basics
# pandas Project: Make a Gradebook With Python & pandas
# advanced
# Grow Your Python Portfolio With 13 Intermediate Project Ideas
# gui
# Creating a Discord Bot in Python
# api
# Build Physical Projects With Python on the Raspberry Pi
# intermediate
# How to Write an Installable Django App
# advanced
# Structuring a Python Application
# basics
# How to Make an Instagram Bot With Python and InstaPy
# intermediate
# ["Create Conway's Game of Life With Python gamedev",
#  'Create a Tic-Tac-Toe Python Game Engine With an AI Player advanced',
#  'Build a Hangman Game With Python and PySimpleGUI basics',
#  "Build Conway's Game of Life With Python gamedev",
#  'Build a Hangman Game for the Command Line in Python basics',
#  'Build a Blog From Scratch With Django django',
#  'Get Started With Django: Build a Portfolio App django',
#  'Create a Python Wordle Clone With Rich basics',
#  'Build a Code Image Generator With Python flask',
#  'Mazes in Python: Build, Visualize, Store, and Solve intermediate',
#  'Build a Maze Solver in Python Using Graphs intermediate',
#  'Build a Wordle Clone With Python and Rich basics',
#  'Build a JavaScript Front End for a Flask API api',
#  'Build a Tic-Tac-Toe Game Engine With an AI Player in Python advanced',
#  'ChatterBot: Build a Chatbot With Python data-science',
#  'Building Python Project Documentation With MkDocs intermediate',
#  'Python and PyQt: Building a GUI Desktop Calculator gui',
#  'Building a URL Shortener With FastAPI and Python api',
#  'Build a Flashcards App With Django django',
#  'Building a Site Connectivity Checker intermediate',
#  'Build Your Python Project Documentation With MkDocs basics',
#  'Build a Quiz Application With Python basics',
#  'Build a URL Shortener With FastAPI and Python api',
#  'Build a Site Connectivity Checker in Python intermediate',
#  'Manage Your To-Do Lists Using Python and Django basics',
#  'Build a Dice-Rolling Application With Python basics',
#  'Build a Command-Line To-Do App With Python and Typer intermediate',
#  'Build a Content Aggregator in Python intermediate',
#  'Using Pygame to Build an Asteroids Game in Python gamedev',
#  'Hosting a Django Project on Heroku django',
#  'Rock, Paper, Scissors With Python: A Command Line Game basics',
#  'Build a Personal Diary With Django and Python basics',
#  'Using sleep() to Code a Python Uptime Bot intermediate',
#  'Using pandas to Make a Gradebook in Python advanced',
#  'Build a Bulk File Rename Tool With Python and PyQt gui',
#  'Build a Python Directory Tree Generator for the Command Line intermediate',
#  'Start Contributing to Python: Your First Steps career',
#  'Build an Asteroids Game With Python and Pygame gamedev',
#  'Build a Contact Book With Python, PyQt, and SQLite databases',
#  'Make Your First Python Game: Rock, Paper, Scissors! basics',
#  'Practical Recipes for Working With Files in Python basics',
#  'pandas Project: Make a Gradebook With Python & pandas advanced',
#  'Grow Your Python Portfolio With 13 Intermediate Project Ideas gui',
#  'Creating a Discord Bot in Python api',
#  'Build Physical Projects With Python on the Raspberry Pi intermediate',
#  'How to Write an Installable Django App advanced',
#  'Structuring a Python Application basics',
#  'How to Make an Instagram Bot With Python and InstaPy intermediate']

# %%
random_project = choices(projects_title)
random_project
# Out:
# ['Build Physical Projects With Python on the Raspberry Pi intermediate']
